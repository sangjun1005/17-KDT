# %%
import matplotlib.pyplot as plt
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
# Out:
# WARNING:tensorflow:From c:\Users\KDS23\Documents\17-image\.venv\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
(train_images, train_labels), (test_images, test_labels) = cifar10.load_data()

# %%
print(train_images.shape, train_labels.shape)
print(test_images.shape, test_labels.shape)
# Out:
# (50000, 32, 32, 3) (50000, 1)
# (10000, 32, 32, 3) (10000, 1)

# %%
train_images[0]
# Out:
# array([[[ 59,  62,  63],
#         [ 43,  46,  45],
#         [ 50,  48,  43],
#         ...,
#         [158, 132, 108],
#         [152, 125, 102],
#         [148, 124, 103]],
#
#        [[ 16,  20,  20],
#         [  0,   0,   0],
#         [ 18,   8,   0],
#         ...,
#         [123,  88,  55],
#         [119,  83,  50],
#         [122,  87,  57]],
#
#        [[ 25,  24,  21],
#         [ 16,   7,   0],
#         [ 49,  27,   8],
#         ...,
#         [118,  84,  50],
#         [120,  84,  50],
#         [109,  73,  42]],
#
#        ...,
#
#        [[208, 170,  96],
#         [201, 153,  34],
#         [198, 161,  26],
#         ...,
#         [160, 133,  70],
#         [ 56,  31,   7],
#         [ 53,  34,  20]],
#
#        [[180, 139,  96],
#         [173, 123,  42],
#         [186, 144,  30],
#         ...,
#         [184, 148,  94],
#         [ 97,  62,  34],
#         [ 83,  53,  34]],
#
#        [[177, 144, 116],
#         [168, 129,  94],
#         [179, 142,  87],
#         ...,
#         [216, 184, 140],
#         [151, 118,  84],
#         [123,  92,  72]]], dtype=uint8)

# %%
plt.figure(figsize=(1,1))
plt.imshow(train_images[32])

# %%
train_images = train_images / 255.0
test_images = test_images / 255.0

# %%
train_images[0]
# Out:
# array([[[0.23137255, 0.24313725, 0.24705882],
#         [0.16862745, 0.18039216, 0.17647059],
#         [0.19607843, 0.18823529, 0.16862745],
#         ...,
#         [0.61960784, 0.51764706, 0.42352941],
#         [0.59607843, 0.49019608, 0.4       ],
#         [0.58039216, 0.48627451, 0.40392157]],
#
#        [[0.0627451 , 0.07843137, 0.07843137],
#         [0.        , 0.        , 0.        ],
#         [0.07058824, 0.03137255, 0.        ],
#         ...,
#         [0.48235294, 0.34509804, 0.21568627],
#         [0.46666667, 0.3254902 , 0.19607843],
#         [0.47843137, 0.34117647, 0.22352941]],
#
#        [[0.09803922, 0.09411765, 0.08235294],
#         [0.0627451 , 0.02745098, 0.        ],
#         [0.19215686, 0.10588235, 0.03137255],
#         ...,
#         [0.4627451 , 0.32941176, 0.19607843],
#         [0.47058824, 0.32941176, 0.19607843],
#         [0.42745098, 0.28627451, 0.16470588]],
#
#        ...,
#
#        [[0.81568627, 0.66666667, 0.37647059],
#         [0.78823529, 0.6       , 0.13333333],
#         [0.77647059, 0.63137255, 0.10196078],
#         ...,
#         [0.62745098, 0.52156863, 0.2745098 ],
#         [0.21960784, 0.12156863, 0.02745098],
#         [0.20784314, 0.13333333, 0.07843137]],
#
#        [[0.70588235, 0.54509804, 0.37647059],
#         [0.67843137, 0.48235294, 0.16470588],
#         [0.72941176, 0.56470588, 0.11764706],
#         ...,
#         [0.72156863, 0.58039216, 0.36862745],
#         [0.38039216, 0.24313725, 0.13333333],
#         [0.3254902 , 0.20784314, 0.13333333]],
#
#        [[0.69411765, 0.56470588, 0.45490196],
#         [0.65882353, 0.50588235, 0.36862745],
#         [0.70196078, 0.55686275, 0.34117647],
#         ...,
#         [0.84705882, 0.72156863, 0.54901961],
#         [0.59215686, 0.4627451 , 0.32941176],
#         [0.48235294, 0.36078431, 0.28235294]]])

# %%
val_images = train_images[45000:]
val_labels = train_labels[45000:]

train_images = train_images[:45000]
train_labels = train_labels[:45000]

# %%
mlp_model = Sequential(
    [Flatten(input_shape = (32, 32, 3)),
     Dense(512, activation= 'relu'),
     Dense(256, activation= 'relu'),
     Dense(128, activation= 'relu'),
     Dense(10, activation= 'softmax')])
# Out:
# WARNING:tensorflow:From c:\Users\KDS23\Documents\17-image\.venv\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %%
mlp_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 3072)              0
#
#  dense (Dense)               (None, 512)               1573376
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  dense_2 (Dense)             (None, 128)               32896
#
#  dense_3 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 1738890 (6.63 MB)
# Trainable params: 1738890 (6.63 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
mlp_model.compile(optimizer= 'adam',
                  loss = 'sparse_categorical_crossentropy',
                  metrics = ['accuracy'])
# Out:
# WARNING:tensorflow:From c:\Users\KDS23\Documents\17-image\.venv\lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
mlp_model.fit(train_images, 
              train_labels, 
              epochs = 5, 
              validation_data = (val_images, val_labels))
# Out:
# Epoch 1/5
# WARNING:tensorflow:From c:\Users\KDS23\Documents\17-image\.venv\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Users\KDS23\Documents\17-image\.venv\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 1407/1407 [==============================] - 6s 4ms/step - loss: 1.8709 - accuracy: 0.3204 - val_loss: 1.7220 - val_accuracy: 0.3868
# Epoch 2/5
# 1407/1407 [==============================] - 5s 4ms/step - loss: 1.6996 - accuracy: 0.3858 - val_loss: 1.6962 - val_accuracy: 0.3926
# Epoch 3/5
# 1407/1407 [==============================] - 5s 4ms/step - loss: 1.6229 - accuracy: 0.4143 - val_loss: 1.5752 - val_accuracy: 0.4328
# Epoch 4/5
# 1407/1407 [==============================] - 5s 4ms/step - loss: 1.5669 - accuracy: 0.4359 - val_loss: 1.5466 - val_accuracy: 0.4498
# Epoch 5/5
# 1407/1407 [==============================] - 6s 4ms/step - loss: 1.5185 - accuracy: 0.4542 - val_loss: 1.5718 - val_accuracy: 0.4432

# %%
mlp_model.evaluate(test_images, test_labels)
# Out:
# 313/313 [==============================] - 0s 1ms/step - loss: 1.5693 - accuracy: 0.4393
# [1.5692967176437378, 0.439300000667572]

# %%
from tensorflow.keras.layers import Conv2D, MaxPool2D, Dropout

# %%
cnn_model = Sequential([
    Conv2D(32,
           (3,3), 
           padding= 'same', 
           activation= 'relu',
           input_shape = (32,32,3)),
           MaxPool2D((2,2)),
           Conv2D(64,
                  (3,3),
                  padding= 'same',
                  activation= 'relu'),
            MaxPool2D((2,2)),
            Conv2D(64,
                   (3,3),
                   padding= 'same',
                   activation= 'relu'),
            Flatten(),
            Dropout(0.3),
            Dense(64,
                  activation= 'relu'),
            Dropout(0.5),
            Dense(10,
                  activation= 'softmax')
])
# Out:
# WARNING:tensorflow:From c:\Users\KDS23\Documents\17-image\.venv\lib\site-packages\keras\src\layers\pooling\max_pooling2d.py:161: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.

# %%
cnn_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 32)        896
#
#  max_pooling2d (MaxPooling2  (None, 16, 16, 32)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 16, 16, 64)        18496
#
#  max_pooling2d_1 (MaxPoolin  (None, 8, 8, 64)          0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 8, 8, 64)          36928
#
#  flatten_1 (Flatten)         (None, 4096)              0
#
#  dropout (Dropout)           (None, 4096)              0
#
#  dense_4 (Dense)             (None, 64)                262208
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_5 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 319178 (1.22 MB)
# Trainable params: 319178 (1.22 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
cnn_model.compile(optimizer= 'adam',
                  loss = 'sparse_categorical_crossentropy',
                  metrics = ['accuracy'])

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

early_stopping = EarlyStopping(monitor= 'val_loss',
                               patience= 5)
save_best_only = ModelCheckpoint('best_cifar10_cnn_model.h5',
                                 save_best_only= True)

# %%
history = cnn_model.fit(train_images,
                        train_labels,
                        batch_size = 512,
                        epochs = 100,
                        validation_data = (val_images,
                                           val_labels),
                        callbacks = [early_stopping,
                                     save_best_only])
# Out:
# Epoch 1/100
# 88/88 [==============================] - 5s 56ms/step - loss: 1.9565 - accuracy: 0.2788 - val_loss: 1.5969 - val_accuracy: 0.4458
# Epoch 2/100
#  2/88 [..............................] - ETA: 4s - loss: 1.7656 - accuracy: 0.3457
# c:\Users\KDS23\Documents\17-image\.venv\lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 88/88 [==============================] - 5s 53ms/step - loss: 1.6186 - accuracy: 0.4090 - val_loss: 1.3921 - val_accuracy: 0.5108
# Epoch 3/100
# 88/88 [==============================] - 5s 53ms/step - loss: 1.4809 - accuracy: 0.4627 - val_loss: 1.3111 - val_accuracy: 0.5302
# Epoch 4/100
# 88/88 [==============================] - 5s 53ms/step - loss: 1.4066 - accuracy: 0.4905 - val_loss: 1.2114 - val_accuracy: 0.5824
# Epoch 5/100
# 88/88 [==============================] - 5s 53ms/step - loss: 1.3351 - accuracy: 0.5204 - val_loss: 1.1696 - val_accuracy: 0.6010
# Epoch 6/100
# 88/88 [==============================] - 5s 54ms/step - loss: 1.2862 - accuracy: 0.5418 - val_loss: 1.0876 - val_accuracy: 0.6168
# Epoch 7/100
100
# 88/88 [==============================] - 5s 59ms/step - loss: 0.7398 - accuracy: 0.7402 - val_loss: 0.7062 - val_accuracy: 0.7564
# Epoch 31/100
# 88/88 [==============================] - 5s 58ms/step - loss: 0.7281 - accuracy: 0.7437 - val_loss: 0.7169 - val_accuracy: 0.7492
# Epoch 32/100
# 88/88 [==============================] - 5s 58ms/step - loss: 0.7260 - accuracy: 0.7430 - val_loss: 0.6962 - val_accuracy: 0.7644
# Epoch 33/100
# 88/88 [==============================] - 5s 59ms/step - loss: 0.7051 - accuracy: 0.7520 - val_loss: 0.7071 - val_accuracy: 0.7554
# Epoch 34/100
# 88/88 [==============================] - 5s 58ms/step - loss: 0.6932 - accuracy: 0.7546 - val_loss: 0.6963 - val_accuracy: 0.7548
# Epoch 35/100
# 88/88 [==============================] - 5s 58ms/step - loss: 0.6906 - accuracy: 0.7544 - val_loss: 0.6909 - val_accuracy: 0.7618
# Epoch 36/100
# 88/88 [==============================] - 5s 58ms/step - loss: 0.6793 - accuracy: 0.7607 - val_loss: 0.6959 - val_accuracy: 0.7668
# Epoch 37/100
# 88/88 [==============================] - 5s 58ms/step - loss: 0.6682 - accuracy: 0.7637 - val_loss: 0.6967 - val_accuracy: 0.7622
# Epoch 38/100
# 88/88 [==============================] - 5s 58ms/step - loss: 0.6687 - accuracy: 0.7643 - val_loss: 0.6791 - val_accuracy: 0.7704
# Epoch 39/100
# 88/88 [==============================] - 5s 59ms/step - loss: 0.6539 - accuracy: 0.7654 - val_loss: 0.6875 - val_accuracy: 0.7646
# Epoch 40/100
# 88/88 [==============================] - 5s 58ms/step - loss: 0.6473 - accuracy: 0.7693 - val_loss: 0.6753 - val_accuracy: 0.7708
# Epoch 41/100
# 88/88 [==============================] - 5s 58ms/step - loss: 0.6318 - accuracy: 0.7755 - val_loss: 0.6863 - val_accuracy: 0.7708
# Epoch 42/100
# 88/88 [==============================] - 5s 58ms/step - loss: 0.6242 - accuracy: 0.7768 - val_loss: 0.6884 - val_accuracy: 0.7676
# Epoch 43/100
# 88/88 [==============================] - 5s 58ms/step - loss: 0.6303 - accuracy: 0.7775 - val_loss: 0.6863 - val_accuracy: 0.7662
# Epoch 44/100
# 88/88 [==============================] - 5s 58ms/step - loss: 0.6145 - accuracy: 0.7798 - val_loss: 0.6780 - val_accuracy: 0.7700
# Epoch 45/100
# 88/88 [==============================] - 5s 58ms/step - loss: 0.6142 - accuracy: 0.7807 - val_loss: 0.6866 - val_accuracy: 0.7700

# %%
plt.plot(history.history['loss'],'b--')
plt.plot(history.history['val_loss'],'r--')
plt.show()

# %%
cnn_model.evaluate(test_images, test_labels)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.7250 - accuracy: 0.7490
# [0.7250484228134155, 0.7490000128746033]

# %%
predicted_labels = cnn_model.predict(test_images)
predicted_labels.shape
# Out:
# 313/313 [==============================] - 1s 2ms/step
# (10000, 10)

# %%
import tensorflow as tf

predicted_labels = tf.argmax(predicted_labels, axis = 1)
predicted_labels
# Out:
# <tf.Tensor: shape=(10000,), dtype=int64, numpy=array([3, 8, 8, ..., 5, 4, 7], dtype=int64)>

# %%
label_to_name = {
    0: 'airplane',
    1: 'automobile',
    2: 'bird',
    3: 'cat',
    4: 'deer',
    5: 'dog',
    6: 'frog',
    7: 'horse',
    8: 'ship',
    9: 'truck'
}

# %%
import matplotlib.pyplot as plt

plt.figure(figsize = (10,10))
for i in range(16):
    plt.subplot(4, 4, i+1)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(test_images[i],
               cmap = plt.cm.binary),
    xlabel = f"{label_to_name[int(test_labels[i][0])]} ({label_to_name[int(predicted_labels[i])]})"
    plt.xlabel(xlabel, color='red'
               if test_labels[i][0] != predicted_labels[i] else 'black')
