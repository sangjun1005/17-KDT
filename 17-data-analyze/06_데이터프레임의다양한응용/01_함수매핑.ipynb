# %%
import seaborn as sns
import pandas as pd

titanic = sns.load_dataset("titanic")
df = titanic.loc[:,['age', 'fare']]

df.head()
# Out:
#     age     fare
# 0  22.0   7.2500
# 1  38.0  71.2833
# 2  26.0   7.9250
# 3  35.0  53.1000
# 4  35.0   8.0500

# %%
def add_10(n):
    return n + 10

def add_two_obj(a,b):
    return a + b

print(add_10(10))
print(add_two_obj(10, 10))
# Out:
# 20
# 20

# %%
sr1 = df['age'].apply(add_10)
sr1.head()
# Out:
# 0    32.0
# 1    48.0
# 2    36.0
# 3    45.0
# 4    45.0
# Name: age, dtype: float64

# %%
sr2 = df['age'].apply(lambda n: n+10)
sr2.head()
# Out:
# 0    32.0
# 1    48.0
# 2    36.0
# 3    45.0
# 4    45.0
# Name: age, dtype: float64

# %%
sr3 = df['age'].apply(add_two_obj, b=10)
sr3.head()
# Out:
# 0    32.0
# 1    48.0
# 2    36.0
# 3    45.0
# 4    45.0
# Name: age, dtype: float64

# %%
sr4 = df['age'].apply(lambda a,b: a+b, b=10)
sr4.head()
# Out:
# 0    32.0
# 1    48.0
# 2    36.0
# 3    45.0
# 4    45.0
# Name: age, dtype: float64

# %%
def over_thirty(age):
    return age>30

sr_map = df['age'].map(over_thirty)
sr_map.head()
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# 4     True
# Name: age, dtype: bool

# %%
sr_map2 = df['age'].map(lambda age: True if age > 30 else False)
sr_map2.head()
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# 4     True
# Name: age, dtype: bool

# %%
print(titanic['sex'].unique())
print('\n')
print(titanic['sex'].head())
print('\n')

over_forty_dict = {'male':0,'female':1}
titanic['gender'] = titanic['sex'].map(over_forty_dict)
print(titanic['gender'].head())
# Out:
# <StringArray>
# ['male', 'female']
# Length: 2, dtype: str
#
#
# 0      male
# 1    female
# 2    female
# 3    female
# 4      male
# Name: sex, dtype: str
#
#
# 0    0
# 1    1
# 2    1
# 3    1
# 4    0
# Name: gender, dtype: int64

# %%
df1 = df.map(add_10)
df1.head()
# Out:
#     age     fare
# 0  32.0  17.2500
# 1  48.0  81.2833
# 2  36.0  17.9250
# 3  45.0  63.1000
# 4  45.0  18.0500

# %%
df2 = df.map(lambda n : n+10)
df2.head()
# Out:
#     age     fare
# 0  32.0  17.2500
# 1  48.0  81.2833
# 2  36.0  17.9250
# 3  45.0  63.1000
# 4  45.0  18.0500

# %%
df3 = df.map(add_two_obj, b=10)
df.head()
# Out:
#     age     fare
# 0  22.0   7.2500
# 1  38.0  71.2833
# 2  26.0   7.9250
# 3  35.0  53.1000
# 4  35.0   8.0500

# %%
df4 = df.map(lambda a,b: a+b, b=10)
df4.head()
# Out:
#     age     fare
# 0  32.0  17.2500
# 1  48.0  81.2833
# 2  36.0  17.9250
# 3  45.0  63.1000
# 4  45.0  18.0500

# %%
def calculate_stats(col):

    max_val = col.max()
    min_val = col.min()
    mean_val = col.mean()
    median_val = col.median()

    return pd.Series([max_val, min_val, mean_val, median_val], index=['max', 'min', 'mean', 'median'])

result_df = df.apply(calculate_stats, axis=0)

result_df
# Out:
#               age        fare
# max     80.000000  512.329200
# min      0.420000    0.000000
# mean    29.699118   32.204208
# median  28.000000   14.454200

# %%
result_sr = df.apply(lambda x: x.max() - x.min(), axis=0)

result_sr
# Out:
# age      79.5800
# fare    512.3292
# dtype: float64

# %%
def calculate_diff_avg(row):
    diff = row.max() - row.min()
    avg = row.mean()
    return pd.Series([diff, avg], index=['차이', '평균'])

result_df2 = df.apply(calculate_diff_avg, axis=1)

result_df2
# Out:
#           차이        평균
# 0    14.7500  14.62500
# 1    33.2833  54.64165
# 2    18.0750  16.96250
# 3    18.1000  44.05000
# 4    26.9500  21.52500
# ..       ...       ...
# 886  14.0000  20.00000
# 887  11.0000  24.50000
# 888   0.0000  23.45000
# 889   4.0000  28.00000
# 890  24.2500  19.87500
#
# [891 rows x 2 columns]

# %%
result_df3 = df.apply(lambda row, multiplier: pd.Series([row.max() - row.min() * multiplier, 
                                             row.mean()],index = ['차이', '평균']), 
                                             multiplier=2, axis=1)

result_df3
# Out:
#           차이        평균
# 0     7.5000  14.62500
# 1    -4.7167  54.64165
# 2    10.1500  16.96250
# 3   -16.9000  44.05000
# 4    18.9000  21.52500
# ..       ...       ...
# 886   1.0000  20.00000
# 887  -8.0000  24.50000
# 888 -23.4500  23.45000
# 889 -22.0000  28.00000
# 890  16.5000  19.87500
#
# [891 rows x 2 columns]

# %%
filtered_columns = df.apply(lambda x: x.mean()>30)
print(filtered_columns, '\n')

filtered_df = df.loc[:, filtered_columns]
filtered_df
# Out:
# age     False
# fare     True
# dtype: bool
#         fare
# 0     7.2500
# 1    71.2833
# 2     7.9250
# 3    53.1000
# 4     8.0500
# ..       ...
# 886  13.0000
# 887  30.0000
# 888  23.4500
# 889  30.0000
# 890   7.7500
#
# [891 rows x 1 columns]

# %%
df['High'] = df.apply(lambda row: 'Yes' if row.mean() > 50 else 'No', axis=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 df['High'] = df.apply(lambda row: 'Yes' if row.mean() > 50 else 'No', axis=1)
#
# File c:\Users\KDS23\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\frame.py:12435, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   12421         raise ValueError(f"Unknown engine '{engine}'")
#   12423     op = frame_apply(
#   12424         self,
#   12425         func=func,
#    (...)  12433         kwargs=kwargs,
#   12434     )
# > 12435     return op.apply().__finalize__(self, method="apply")
#   12436 elif hasattr(engine, "__pandas_udf__"):
#   12437     if result_type is not None:
#
# File c:\Users\KDS23\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\apply.py:1015, in FrameApply.apply(self)
#    1012 elif self.raw:
#    1013     return self.apply_raw(engine=self.engine, engine_kwargs=self.engine_kwargs)
# -> 1015 return self.apply_standard()
#
# File c:\Users\KDS23\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\apply.py:1167, in FrameApply.apply_standard(self)
#    1165 def apply_standard(self):
#    1166     if self.engine == "python":
# -> 1167         results, res_index = self.apply_series_generator()
#    1168     else:
#    1169         results, res_index = self.apply_series_numba()
#
# File c:\Users\KDS23\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\apply.py:1183, in FrameApply.apply_series_generator(self)
#    1180 results = {}
#    1182 for i, v in enumerate(series_gen):
# -> 1183     results[i] = self.func(v, *self.args, **self.kwargs)
#    1184     if isinstance(results[i], ABCSeries):
#    1185         # If we have a view on v, we need to make a copy because
#    1186         #  series_generator will swap out the underlying data
#    1187         results[i] = results[i].copy(deep=False)
#
# Cell In[34], line 1, in <lambda>(row)
# ----> 1 df['High'] = df.apply(lambda row: 'Yes' if row.mean() > 50 else 'No', axis=1)
#
# File c:\Users\KDS23\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\util\_decorators.py:336, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     330 if len(args) > num_allow_args:
#     331     warnings.warn(
#     332         msg.format(arguments=_format_argument_list(allow_args)),
#     333         klass,
#     334         stacklevel=find_stack_level(),
#     335     )
# --> 336 return func(*args, **kwargs)
#
# File c:\Users\KDS23\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\series.py:8113, in Series.mean(self, axis, skipna, numeric_only, **kwargs)
#    8063 @deprecate_nonkeyword_arguments(Pandas4Warning, allowed_args=["self"], name="mean")
#    8064 def mean(
#    8065     self,
#    (...)   8069     **kwargs,
#    8070 ) -> Any:
#    8071     """
#    8072     Return the mean of the values over the requested axis.
#    8073
#    (...)   8111     2.0
#    8112     """
# -> 8113     return NDFrame.mean(
#    8114         self, axis=axis, skipna=skipna, numeric_only=numeric_only, **kwargs
#    8115     )
#
# File c:\Users\KDS23\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\generic.py:11831, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11823 def mean(
#   11824     self,
#   11825     *,
#    (...)  11829     **kwargs,
#   11830 ) -> Series | float:
# > 11831     return self._stat_function(
#   11832         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   11833     )
#
# File c:\Users\KDS23\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\generic.py:11785, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   11781 nv.validate_func(name, (), kwargs)
#   11783 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 11785 return self._reduce(
#   11786     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11787 )
#
# File c:\Users\KDS23\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\series.py:7494, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    7489         # GH#47500 - change to TypeError to match other methods
#    7490         raise TypeError(
#    7491             f"Series.{name} does not allow {kwd_name}={numeric_only} "
#    7492             "with non-numeric dtypes."
#    7493         )
# -> 7494     result = op(delegate, skipna=skipna, **kwds)
#    7496 result = maybe_unbox_numpy_scalar(result)
#    7497 return result
#
# File c:\Users\KDS23\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\nanops.py:149, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     147         result = alt(values, axis=axis, skipna=skipna, **kwds)
#     148 else:
# --> 149     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     151 return result
#
# File c:\Users\KDS23\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\nanops.py:408, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     405 if datetimelike and mask is None:
#     406     mask = isna(values)
# --> 408 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     410 if datetimelike:
#     411     result = _wrap_results(result, orig_values.dtype, fill_value=iNaT)
#
# File c:\Users\KDS23\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\nanops.py:713, in nanmean(values, axis, skipna, mask)
#     710     dtype_count = dtype
#     712 count = _get_counts(values.shape, mask, axis, dtype=dtype_count)
# --> 713 the_sum = values.sum(axis, dtype=dtype_sum)
#     714 the_sum = _ensure_numeric(the_sum)
#     716 if axis is not None and getattr(the_sum, "ndim", False):
#
# File c:\Users\KDS23\AppData\Local\Programs\Python\Python314\Lib\site-packages\numpy\_core\_methods.py:49, in _sum(a, axis, dtype, out, keepdims, initial, where)
#      47 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      48          initial=_NoValue, where=True):
# ---> 49     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#
# TypeError: unsupported operand type(s) for +: 'float' and 'str'

# %%
df
# Out:
#       age     fare High
# 0    22.0   7.2500   No
# 1    38.0  71.2833  Yes
# 2    26.0   7.9250   No
# 3    35.0  53.1000   No
# 4    35.0   8.0500   No
# ..    ...      ...  ...
# 886  27.0  13.0000   No
# 887  19.0  30.0000   No
# 888   NaN  23.4500   No
# 889  26.0  30.0000   No
# 890  32.0   7.7500   No
#
# [891 rows x 3 columns]

# %%
df1 = titanic.loc[:,['age', 'fare']]
df2 = titanic.loc[:,['embark_town','embarked']]

def missing_value(df):
    return df.isnull()

result_df = df1.pipe(missing_value)
result_df
# Out:
#        age   fare
# 0    False  False
# 1    False  False
# 2    False  False
# 3    False  False
# 4    False  False
# ..     ...    ...
# 886  False  False
# 887  False  False
# 888   True  False
# 889  False  False
# 890  False  False
#
# [891 rows x 2 columns]

# %%
def missing_count(df):
    return missing_value(df).sum()

result_series = df1.pipe(missing_count)
result_series
# Out:
# age     177
# fare      0
# dtype: int64

# %%
def total_number_missing(df):
    return missing_count(df).sum()

result_value = df1.pipe(total_number_missing)
print(result_value)
# Out:
# 177

# %%
def extract_initial(df):
    df['town_initial'] = df['embark_town'].str[0]
    return df

def verify_initial(df):
    df['verified'] = df["embarked"] == df['town_initial']
    return df

verify_initial(extract_initial(df2))
# Out:
#      embark_town embarked town_initial  verified
# 0    Southampton        S            S      True
# 1      Cherbourg        C            C      True
# 2    Southampton        S            S      True
# 3    Southampton        S            S      True
# 4    Southampton        S            S      True
# ..           ...      ...          ...       ...
# 886  Southampton        S            S      True
# 887  Southampton        S            S      True
# 888  Southampton        S            S      True
# 889    Cherbourg        C            C      True
# 890   Queenstown        Q            Q      True
#
# [891 rows x 4 columns]

# %%
embark_town = df2.pipe(extract_initial).pipe(verify_initial)
embark_town
# Out:
#      embark_town embarked town_initial  verified
# 0    Southampton        S            S      True
# 1      Cherbourg        C            C      True
# 2    Southampton        S            S      True
# 3    Southampton        S            S      True
# 4    Southampton        S            S      True
# ..           ...      ...          ...       ...
# 886  Southampton        S            S      True
# 887  Southampton        S            S      True
# 888  Southampton        S            S      True
# 889    Cherbourg        C            C      True
# 890   Queenstown        Q            Q      True
#
# [891 rows x 4 columns]
