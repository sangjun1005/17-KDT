# %%
import pandas as pd

df = pd.read_csv('./data/stock-data.csv')

print(df.head())
print('\n')
print(df.info())
# Out:
#          Date  Close  Start   High    Low  Volume
# 0  2018-07-02  10100  10850  10900  10000  137977
# 1  2018-06-29  10700  10550  10900   9990  170253
# 2  2018-06-28  10400  10900  10950  10150  155769
# 3  2018-06-27  10900  10800  11050  10500  133548
# 4  2018-06-26  10800  10900  11000  10700   63039
#
#
# <class 'pandas.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    20 non-null     str
#  1   Close   20 non-null     int64
#  2   Start   20 non-null     int64
#  3   High    20 non-null     int64
#  4   Low     20 non-null     int64
#  5   Volume  20 non-null     int64
# dtypes: int64(5), str(1)
# memory usage: 1.1 KB
# None

# %%
df['new_Date'] = pd.to_datetime(df['Date'])

print(df.head())
print('\n')
print(df.info())
print('\n')
print(type(df['new_Date'][0]))
# Out:
#          Date  Close  Start   High    Low  Volume   new_Date
# 0  2018-07-02  10100  10850  10900  10000  137977 2018-07-02
# 1  2018-06-29  10700  10550  10900   9990  170253 2018-06-29
# 2  2018-06-28  10400  10900  10950  10150  155769 2018-06-28
# 3  2018-06-27  10900  10800  11050  10500  133548 2018-06-27
# 4  2018-06-26  10800  10900  11000  10700   63039 2018-06-26
#
#
# <class 'pandas.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      20 non-null     str
#  1   Close     20 non-null     int64
#  2   Start     20 non-null     int64
#  3   High      20 non-null     int64
#  4   Low       20 non-null     int64
#  5   Volume    20 non-null     int64
#  6   new_Date  20 non-null     datetime64[us]
# dtypes: datetime64[us](1), int64(5), str(1)
# memory usage: 1.2 KB
# None
#
#
# <class 'pandas.Timestamp'>

# %%
df = df.set_index('new_Date')
df = df.drop('Date',axis=1)

print(df.head())
print('\n')
print(df.info())
# Out:
#             Close  Start   High    Low  Volume
# new_Date
# 2018-07-02  10100  10850  10900  10000  137977
# 2018-06-29  10700  10550  10900   9990  170253
# 2018-06-28  10400  10900  10950  10150  155769
# 2018-06-27  10900  10800  11050  10500  133548
# 2018-06-26  10800  10900  11000  10700   63039
#
#
# <class 'pandas.DataFrame'>
# DatetimeIndex: 20 entries, 2018-07-02 to 2018-06-01
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Close   20 non-null     int64
#  1   Start   20 non-null     int64
#  2   High    20 non-null     int64
#  3   Low     20 non-null     int64
#  4   Volume  20 non-null     int64
# dtypes: int64(5)
# memory usage: 960.0 bytes
# None

# %%
pd.DatetimeIndex(['2022-12-25','2023/01/25'])
# Out:
# DatetimeIndex(['2022-12-25', '2023-01-25'], dtype='datetime64[us]', freq=None)

# %%
pd.Timestamp('2023-12-25')
# Out:
# Timestamp('2023-12-25 00:00:00')

# %%
pd.to_datetime('2023년 12월 25일', format='%Y년 %m월 %d일')
# Out:
# Timestamp('2023-12-25 00:00:00')

# %%
pd.to_datetime('12-12-2023 23:59:59', format='%d-%m-%Y %H:%M:%S')
# Out:
# Timestamp('2023-12-12 23:59:59')

# %%
dates = ['2019-01-01', '2020-03-01', '2021-06-01']

ts_dates = pd.to_datetime(dates)
print(ts_dates)
# Out:
# DatetimeIndex(['2019-01-01', '2020-03-01', '2021-06-01'], dtype='datetime64[us]', freq=None)

# %%
pr_day = ts_dates.to_period(freq='D')
print(pr_day)
# Out:
# PeriodIndex(['2019-01-01', '2020-03-01', '2021-06-01'], dtype='period[D]')

# %%
pr_month = ts_dates.to_period(freq='M')
print(pr_month)
# Out:
# PeriodIndex(['2019-01', '2020-03', '2021-06'], dtype='period[M]')

# %%
pr_year = ts_dates.to_period(freq='Y')
print(pr_year)
# Out:
# PeriodIndex(['2019', '2020', '2021'], dtype='period[Y-DEC]')

# %%
ts_ms = pd.date_range(
    start='2024-01-01',
    end=None,
    periods=6,
    freq='MS',
    tz='Asia/Seoul'
)

print(ts_ms)
# Out:
# DatetimeIndex(['2024-01-01 00:00:00+09:00', '2024-02-01 00:00:00+09:00',
#                '2024-03-01 00:00:00+09:00', '2024-04-01 00:00:00+09:00',
#                '2024-05-01 00:00:00+09:00', '2024-06-01 00:00:00+09:00'],
#               dtype='datetime64[us, Asia/Seoul]', freq='MS')

# %%
ts_me = pd.date_range(
    '2024-01-01',
    periods=6,
    freq='ME',
    tz='Asia/Seoul'
)

print(ts_me)
# Out:
# DatetimeIndex(['2024-01-31 00:00:00+09:00', '2024-02-29 00:00:00+09:00',
#                '2024-03-31 00:00:00+09:00', '2024-04-30 00:00:00+09:00',
#                '2024-05-31 00:00:00+09:00', '2024-06-30 00:00:00+09:00'],
#               dtype='datetime64[us, Asia/Seoul]', freq='ME')

# %%
ts_3m = pd.date_range(
    '2024-01-01',
    periods=6,
    freq='3MS',
    tz='Asia/Seoul'
)

print(ts_3m)
# Out:
# DatetimeIndex(['2024-01-01 00:00:00+09:00', '2024-04-01 00:00:00+09:00',
#                '2024-07-01 00:00:00+09:00', '2024-10-01 00:00:00+09:00',
#                '2025-01-01 00:00:00+09:00', '2025-04-01 00:00:00+09:00'],
#               dtype='datetime64[us, Asia/Seoul]', freq='3MS')

# %%
df = pd.read_csv('./data/stock-data.csv')

df['new_Date'] = pd.to_datetime(df['Date'])
df.head()
# Out:
#          Date  Close  Start   High    Low  Volume   new_Date
# 0  2018-07-02  10100  10850  10900  10000  137977 2018-07-02
# 1  2018-06-29  10700  10550  10900   9990  170253 2018-06-29
# 2  2018-06-28  10400  10900  10950  10150  155769 2018-06-28
# 3  2018-06-27  10900  10800  11050  10500  133548 2018-06-27
# 4  2018-06-26  10800  10900  11000  10700   63039 2018-06-26

# %%
df['Year'] = df['new_Date'].dt.year
df['Month'] = df['new_Date'].dt.month
df['Day'] = df['new_Date'].dt.day

# %%
df.head()
# Out:
#          Date  Close  Start   High    Low  Volume   new_Date  Year  Month  Day
# 0  2018-07-02  10100  10850  10900  10000  137977 2018-07-02  2018      7    2
# 1  2018-06-29  10700  10550  10900   9990  170253 2018-06-29  2018      6   29
# 2  2018-06-28  10400  10900  10950  10150  155769 2018-06-28  2018      6   28
# 3  2018-06-27  10900  10800  11050  10500  133548 2018-06-27  2018      6   27
# 4  2018-06-26  10800  10900  11000  10700   63039 2018-06-26  2018      6   26

# %%
df['Date_yr'] = df['new_Date'].dt.to_period(freq='Y')
df['Date_m'] = df['new_Date'].dt.to_period(freq='M')

df.head()
# Out:
#          Date  Close  Start   High    Low  Volume   new_Date  Year  Month  \
# 0  2018-07-02  10100  10850  10900  10000  137977 2018-07-02  2018      7
# 1  2018-06-29  10700  10550  10900   9990  170253 2018-06-29  2018      6
# 2  2018-06-28  10400  10900  10950  10150  155769 2018-06-28  2018      6
# 3  2018-06-27  10900  10800  11050  10500  133548 2018-06-27  2018      6
# 4  2018-06-26  10800  10900  11000  10700   63039 2018-06-26  2018      6
#
#    Day Date_yr   Date_m
# 0    2    2018  2018-07
# 1   29    2018  2018-06
# 2   28    2018  2018-06
# 3   27    2018  2018-06
# 4   26    2018  2018-06

# %%
df_june = df[df['Date_m'].astype(str).str.fullmatch('2018-06')]
df_june.head()
# Out:
#          Date  Close  Start   High    Low  Volume   new_Date  Year  Month  \
# 1  2018-06-29  10700  10550  10900   9990  170253 2018-06-29  2018      6
# 2  2018-06-28  10400  10900  10950  10150  155769 2018-06-28  2018      6
# 3  2018-06-27  10900  10800  11050  10500  133548 2018-06-27  2018      6
# 4  2018-06-26  10800  10900  11000  10700   63039 2018-06-26  2018      6
# 5  2018-06-25  11150  11400  11450  11000   55519 2018-06-25  2018      6
#
#    Day Date_yr   Date_m
# 1   29    2018  2018-06
# 2   28    2018  2018-06
# 3   27    2018  2018-06
# 4   26    2018  2018-06
# 5   25    2018  2018-06

# %%
df_june = df_june.set_index('new_Date')
df_june.head()
# Out:
#                   Date  Close  Start   High    Low  Volume  Year  Month  Day  \
# new_Date
# 2018-06-29  2018-06-29  10700  10550  10900   9990  170253  2018      6   29
# 2018-06-28  2018-06-28  10400  10900  10950  10150  155769  2018      6   28
# 2018-06-27  2018-06-27  10900  10800  11050  10500  133548  2018      6   27
# 2018-06-26  2018-06-26  10800  10900  11000  10700   63039  2018      6   26
# 2018-06-25  2018-06-25  11150  11400  11450  11000   55519  2018      6   25
#
#            Date_yr   Date_m
# new_Date
# 2018-06-29    2018  2018-06
# 2018-06-28    2018  2018-06
# 2018-06-27    2018  2018-06
# 2018-06-26    2018  2018-06
# 2018-06-25    2018  2018-06

# %%
df
# Out:
#           Date  Close  Start   High    Low  Volume   new_Date  Year  Month  \
# 0   2018-07-02  10100  10850  10900  10000  137977 2018-07-02  2018      7
# 1   2018-06-29  10700  10550  10900   9990  170253 2018-06-29  2018      6
# 2   2018-06-28  10400  10900  10950  10150  155769 2018-06-28  2018      6
# 3   2018-06-27  10900  10800  11050  10500  133548 2018-06-27  2018      6
# 4   2018-06-26  10800  10900  11000  10700   63039 2018-06-26  2018      6
# 5   2018-06-25  11150  11400  11450  11000   55519 2018-06-25  2018      6
# 6   2018-06-22  11300  11250  11450  10750  134805 2018-06-22  2018      6
# 7   2018-06-21  11200  11350  11750  11200  133002 2018-06-21  2018      6
# 8   2018-06-20  11550  11200  11600  10900  308596 2018-06-20  2018      6
# 9   2018-06-19  11300  11850  11950  11300  180656 2018-06-19  2018      6
# 10  2018-06-18  12000  13400  13400  12000  309787 2018-06-18  2018      6
# 11  2018-06-15  13400  13600  13600  12900  201376 2018-06-15  2018      6
# 12  2018-06-14  13450  13200  13700  13150  347451 2018-06-14  2018      6
# 13  2018-06-12  13200  12200  13300  12050  558148 2018-06-12  2018      6
# 14  2018-06-11  11950  12000  12250  11950   62293 2018-06-11  2018      6
# 15  2018-06-08  11950  11950  12200  11800   59258 2018-06-08  2018      6
# 16  2018-06-07  11950  12200  12300  11900   49088 2018-06-07  2018      6
# 17  2018-06-05  12150  11800  12250  11800   42485 2018-06-05  2018      6
# 18  2018-06-04  11900  11900  12200  11700   25171 2018-06-04  2018      6
# 19  2018-06-01  11900  11800  12100  11750   32062 2018-06-01  2018      6
#
#     Day Date_yr   Date_m
# 0     2    2018  2018-07
# 1    29    2018  2018-06
# 2    28    2018  2018-06
# 3    27    2018  2018-06
# 4    26    2018  2018-06
# 5    25    2018  2018-06
# 6    22    2018  2018-06
# 7    21    2018  2018-06
# 8    20    2018  2018-06
# 9    19    2018  2018-06
# 10   18    2018  2018-06
# 11   15    2018  2018-06
# 12   14    2018  2018-06
# 13   12    2018  2018-06
# 14   11    2018  2018-06
# 15    8    2018  2018-06
# 16    7    2018  2018-06
# 17    5    2018  2018-06
# 18    4    2018  2018-06
# 19    1    2018  2018-06

# %%
df = pd.read_csv('./data/stock-data.csv')
df
# Out:
#           Date  Close  Start   High    Low  Volume
# 0   2018-07-02  10100  10850  10900  10000  137977
# 1   2018-06-29  10700  10550  10900   9990  170253
# 2   2018-06-28  10400  10900  10950  10150  155769
# 3   2018-06-27  10900  10800  11050  10500  133548
# 4   2018-06-26  10800  10900  11000  10700   63039
# 5   2018-06-25  11150  11400  11450  11000   55519
# 6   2018-06-22  11300  11250  11450  10750  134805
# 7   2018-06-21  11200  11350  11750  11200  133002
# 8   2018-06-20  11550  11200  11600  10900  308596
# 9   2018-06-19  11300  11850  11950  11300  180656
# 10  2018-06-18  12000  13400  13400  12000  309787
# 11  2018-06-15  13400  13600  13600  12900  201376
# 12  2018-06-14  13450  13200  13700  13150  347451
# 13  2018-06-12  13200  12200  13300  12050  558148
# 14  2018-06-11  11950  12000  12250  11950   62293
# 15  2018-06-08  11950  11950  12200  11800   59258
# 16  2018-06-07  11950  12200  12300  11900   49088
# 17  2018-06-05  12150  11800  12250  11800   42485
# 18  2018-06-04  11900  11900  12200  11700   25171
# 19  2018-06-01  11900  11800  12100  11750   32062

# %%
df['new_Date'] = pd.to_datetime(df['Date'])

df = df.set_index('new_Date').sort_index()
df
# Out:
#                   Date  Close  Start   High    Low  Volume
# new_Date
# 2018-06-01  2018-06-01  11900  11800  12100  11750   32062
# 2018-06-04  2018-06-04  11900  11900  12200  11700   25171
# 2018-06-05  2018-06-05  12150  11800  12250  11800   42485
# 2018-06-07  2018-06-07  11950  12200  12300  11900   49088
# 2018-06-08  2018-06-08  11950  11950  12200  11800   59258
# 2018-06-11  2018-06-11  11950  12000  12250  11950   62293
# 2018-06-12  2018-06-12  13200  12200  13300  12050  558148
# 2018-06-14  2018-06-14  13450  13200  13700  13150  347451
# 2018-06-15  2018-06-15  13400  13600  13600  12900  201376
# 2018-06-18  2018-06-18  12000  13400  13400  12000  309787
# 2018-06-19  2018-06-19  11300  11850  11950  11300  180656
# 2018-06-20  2018-06-20  11550  11200  11600  10900  308596
# 2018-06-21  2018-06-21  11200  11350  11750  11200  133002
# 2018-06-22  2018-06-22  11300  11250  11450  10750  134805
# 2018-06-25  2018-06-25  11150  11400  11450  11000   55519
# 2018-06-26  2018-06-26  10800  10900  11000  10700   63039
# 2018-06-27  2018-06-27  10900  10800  11050  10500  133548
# 2018-06-28  2018-06-28  10400  10900  10950  10150  155769
# 2018-06-29  2018-06-29  10700  10550  10900   9990  170253
# 2018-07-02  2018-07-02  10100  10850  10900  10000  137977

# %%
df.loc['2018-06-27']
# Out:
# Date      2018-06-27
# Close          10900
# Start          10800
# High           11050
# Low            10500
# Volume        133548
# Name: 2018-06-27 00:00:00, dtype: object

# %%
df.loc['2018-07']
# Out:
#                   Date  Close  Start   High    Low  Volume
# new_Date
# 2018-07-02  2018-07-02  10100  10850  10900  10000  137977

# %%
df.loc['2018-06-27':'2018-07-02']
# Out:
#                   Date  Close  Start   High    Low  Volume
# new_Date
# 2018-06-27  2018-06-27  10900  10800  11050  10500  133548
# 2018-06-28  2018-06-28  10400  10900  10950  10150  155769
# 2018-06-29  2018-06-29  10700  10550  10900   9990  170253
# 2018-07-02  2018-07-02  10100  10850  10900  10000  137977

# %%
df[df.index < '2018-06-05']
# Out:
#                   Date  Close  Start   High    Low  Volume
# new_Date
# 2018-06-01  2018-06-01  11900  11800  12100  11750   32062
# 2018-06-04  2018-06-04  11900  11900  12200  11700   25171

# %%
df.loc[pd.Timestamp(2018,6,27):pd.Timestamp(2018,7,2)]
# Out:
#                   Date  Close  Start   High    Low  Volume
# new_Date
# 2018-06-27  2018-06-27  10900  10800  11050  10500  133548
# 2018-06-28  2018-06-28  10400  10900  10950  10150  155769
# 2018-06-29  2018-06-29  10700  10550  10900   9990  170253
# 2018-07-02  2018-07-02  10100  10850  10900  10000  137977

# %%
df.loc[pd.Timestamp(2018,6,27,10,30,0):pd.Timestamp(2018,7,2,23,59,59)]
# Out:
#                   Date  Close  Start   High    Low  Volume
# new_Date
# 2018-06-28  2018-06-28  10400  10900  10950  10150  155769
# 2018-06-29  2018-06-29  10700  10550  10900   9990  170253
# 2018-07-02  2018-07-02  10100  10850  10900  10000  137977

# %%
print(pd.Timedelta('1 days'))
print(pd.Timedelta(days=1))
print(pd.Timedelta('1 days 1 hours 1 minutes 1 seconds'))
print(pd.Timedelta(days=1, hours=1, minutes=1, seconds=1))
# Out:
# 1 days 00:00:00
# 1 days 00:00:00
# 1 days 01:01:01
# 1 days 01:01:01

# %%
pd.to_timedelta(['1days', '3hours'])
# Out:
# TimedeltaIndex(['1 days 00:00:00', '0 days 03:00:00'], dtype='timedelta64[us]', freq=None)

# %%
a = df.index
print(a)
# Out:
# DatetimeIndex(['2018-06-01', '2018-06-04', '2018-06-05', '2018-06-07',
#                '2018-06-08', '2018-06-11', '2018-06-12', '2018-06-14',
#                '2018-06-15', '2018-06-18', '2018-06-19', '2018-06-20',
#                '2018-06-21', '2018-06-22', '2018-06-25', '2018-06-26',
#                '2018-06-27', '2018-06-28', '2018-06-29', '2018-07-02'],
#               dtype='datetime64[us]', name='new_Date', freq=None)

# %%
b = pd.Timestamp('2018-07-03') - a
print(b)
# Out:
# TimedeltaIndex(['32 days', '29 days', '28 days', '26 days', '25 days',
#                 '22 days', '21 days', '19 days', '18 days', '15 days',
#                 '14 days', '13 days', '12 days', '11 days',  '8 days',
#                  '7 days',  '6 days',  '5 days',  '4 days',  '1 days'],
#                dtype='timedelta64[us]', name='new_Date', freq=None)

# %%
c = a + pd.Timedelta(days=1)
print(c)
# Out:
# DatetimeIndex(['2018-06-02', '2018-06-05', '2018-06-06', '2018-06-08',
#                '2018-06-09', '2018-06-12', '2018-06-13', '2018-06-15',
#                '2018-06-16', '2018-06-19', '2018-06-20', '2018-06-21',
#                '2018-06-22', '2018-06-23', '2018-06-26', '2018-06-27',
#                '2018-06-28', '2018-06-29', '2018-06-30', '2018-07-03'],
#               dtype='datetime64[us]', name='new_Date', freq=None)

# %%
print(c.min())
print(c.max(
))
# Out:
# 2018-06-02 00:00:00
# 2018-07-03 00:00:00

# %%
df
# Out:
#                   Date  Close  Start   High    Low  Volume
# new_Date
# 2018-06-01  2018-06-01  11900  11800  12100  11750   32062
# 2018-06-04  2018-06-04  11900  11900  12200  11700   25171
# 2018-06-05  2018-06-05  12150  11800  12250  11800   42485
# 2018-06-07  2018-06-07  11950  12200  12300  11900   49088
# 2018-06-08  2018-06-08  11950  11950  12200  11800   59258
# 2018-06-11  2018-06-11  11950  12000  12250  11950   62293
# 2018-06-12  2018-06-12  13200  12200  13300  12050  558148
# 2018-06-14  2018-06-14  13450  13200  13700  13150  347451
# 2018-06-15  2018-06-15  13400  13600  13600  12900  201376
# 2018-06-18  2018-06-18  12000  13400  13400  12000  309787
# 2018-06-19  2018-06-19  11300  11850  11950  11300  180656
# 2018-06-20  2018-06-20  11550  11200  11600  10900  308596
# 2018-06-21  2018-06-21  11200  11350  11750  11200  133002
# 2018-06-22  2018-06-22  11300  11250  11450  10750  134805
# 2018-06-25  2018-06-25  11150  11400  11450  11000   55519
# 2018-06-26  2018-06-26  10800  10900  11000  10700   63039
# 2018-06-27  2018-06-27  10900  10800  11050  10500  133548
# 2018-06-28  2018-06-28  10400  10900  10950  10150  155769
# 2018-06-29  2018-06-29  10700  10550  10900   9990  170253
# 2018-07-02  2018-07-02  10100  10850  10900  10000  137977

# %%
df = pd.read_csv('./data/stock-data.csv')

df['new_Date'] = pd.to_datetime(df['Date'])
df = df.drop(columns=['Date'])

df = df.set_index('new_Date').sort_index()

ts = df.head(10)
ts
# Out:
#             Close  Start   High    Low  Volume
# new_Date
# 2018-06-01  11900  11800  12100  11750   32062
# 2018-06-04  11900  11900  12200  11700   25171
# 2018-06-05  12150  11800  12250  11800   42485
# 2018-06-07  11950  12200  12300  11900   49088
# 2018-06-08  11950  11950  12200  11800   59258
# 2018-06-11  11950  12000  12250  11950   62293
# 2018-06-12  13200  12200  13300  12050  558148
# 2018-06-14  13450  13200  13700  13150  347451
# 2018-06-15  13400  13600  13600  12900  201376
# 2018-06-18  12000  13400  13400  12000  309787

# %%
ts.shift(1)
# Out:
#               Close    Start     High      Low    Volume
# new_Date
# 2018-06-01      NaN      NaN      NaN      NaN       NaN
# 2018-06-04  11900.0  11800.0  12100.0  11750.0   32062.0
# 2018-06-05  11900.0  11900.0  12200.0  11700.0   25171.0
# 2018-06-07  12150.0  11800.0  12250.0  11800.0   42485.0
# 2018-06-08  11950.0  12200.0  12300.0  11900.0   49088.0
# 2018-06-11  11950.0  11950.0  12200.0  11800.0   59258.0
# 2018-06-12  11950.0  12000.0  12250.0  11950.0   62293.0
# 2018-06-14  13200.0  12200.0  13300.0  12050.0  558148.0
# 2018-06-15  13450.0  13200.0  13700.0  13150.0  347451.0
# 2018-06-18  13400.0  13600.0  13600.0  12900.0  201376.0

# %%
ts.shift(-2)
# Out:
#               Close    Start     High      Low    Volume
# new_Date
# 2018-06-01  12150.0  11800.0  12250.0  11800.0   42485.0
# 2018-06-04  11950.0  12200.0  12300.0  11900.0   49088.0
# 2018-06-05  11950.0  11950.0  12200.0  11800.0   59258.0
# 2018-06-07  11950.0  12000.0  12250.0  11950.0   62293.0
# 2018-06-08  13200.0  12200.0  13300.0  12050.0  558148.0
# 2018-06-11  13450.0  13200.0  13700.0  13150.0  347451.0
# 2018-06-12  13400.0  13600.0  13600.0  12900.0  201376.0
# 2018-06-14  12000.0  13400.0  13400.0  12000.0  309787.0
# 2018-06-15      NaN      NaN      NaN      NaN       NaN
# 2018-06-18      NaN      NaN      NaN      NaN       NaN

# %%
ts.shift(3,freq='D')
# Out:
#             Close  Start   High    Low  Volume
# new_Date
# 2018-06-04  11900  11800  12100  11750   32062
# 2018-06-07  11900  11900  12200  11700   25171
# 2018-06-08  12150  11800  12250  11800   42485
# 2018-06-10  11950  12200  12300  11900   49088
# 2018-06-11  11950  11950  12200  11800   59258
# 2018-06-14  11950  12000  12250  11950   62293
# 2018-06-15  13200  12200  13300  12050  558148
# 2018-06-17  13450  13200  13700  13150  347451
# 2018-06-18  13400  13600  13600  12900  201376
# 2018-06-21  12000  13400  13400  12000  309787

# %%
ts.asfreq('5D')
# Out:
#               Close    Start     High      Low   Volume
# new_Date
# 2018-06-01  11900.0  11800.0  12100.0  11750.0  32062.0
# 2018-06-06      NaN      NaN      NaN      NaN      NaN
# 2018-06-11  11950.0  12000.0  12250.0  11950.0  62293.0
# 2018-06-16      NaN      NaN      NaN      NaN      NaN

# %%
ts.asfreq('5D',method='bfill')
# Out:
#             Close  Start   High    Low  Volume
# new_Date
# 2018-06-01  11900  11800  12100  11750   32062
# 2018-06-06  11950  12200  12300  11900   49088
# 2018-06-11  11950  12000  12250  11950   62293
# 2018-06-16  12000  13400  13400  12000  309787

# %%
print(ts.resample('3B'))
ts.resample('3B').sum()
# Out:
# DatetimeIndexResampler [freq=<3 * BusinessDays>, closed=left, label=left, convention=start, origin=start_day]
#             Close  Start   High    Low  Volume
# new_Date
# 2018-06-01  35950  35500  36550  35250   99718
# 2018-06-06  23900  24150  24500  23700  108346
# 2018-06-11  25150  24200  25550  24000  620441
# 2018-06-14  38850  40200  40700  38050  858614

# %%
ts.rolling(window=3).sum()
# Out:
#               Close    Start     High      Low     Volume
# new_Date
# 2018-06-01      NaN      NaN      NaN      NaN        NaN
# 2018-06-04      NaN      NaN      NaN      NaN        NaN
# 2018-06-05  35950.0  35500.0  36550.0  35250.0    99718.0
# 2018-06-07  36000.0  35900.0  36750.0  35400.0   116744.0
# 2018-06-08  36050.0  35950.0  36750.0  35500.0   150831.0
# 2018-06-11  35850.0  36150.0  36750.0  35650.0   170639.0
# 2018-06-12  37100.0  36150.0  37750.0  35800.0   679699.0
# 2018-06-14  38600.0  37400.0  39250.0  37150.0   967892.0
# 2018-06-15  40050.0  39000.0  40600.0  38100.0  1106975.0
# 2018-06-18  38850.0  40200.0  40700.0  38050.0   858614.0

# %%
ts.rolling(window='3D').sum()
# Out:
#               Close    Start     High      Low    Volume
# new_Date
# 2018-06-01  11900.0  11800.0  12100.0  11750.0   32062.0
# 2018-06-04  11900.0  11900.0  12200.0  11700.0   25171.0
# 2018-06-05  24050.0  23700.0  24450.0  23500.0   67656.0
# 2018-06-07  24100.0  24000.0  24550.0  23700.0   91573.0
# 2018-06-08  23900.0  24150.0  24500.0  23700.0  108346.0
# 2018-06-11  11950.0  12000.0  12250.0  11950.0   62293.0
# 2018-06-12  25150.0  24200.0  25550.0  24000.0  620441.0
# 2018-06-14  26650.0  25400.0  27000.0  25200.0  905599.0
# 2018-06-15  26850.0  26800.0  27300.0  26050.0  548827.0
# 2018-06-18  12000.0  13400.0  13400.0  12000.0  309787.0

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

df = pd.read_csv('./data/stock-data.csv')

df['new_Date'] = pd.to_datetime(df['Date'])
df = df.drop(columns=['Date'])

df = df.set_index('new_Date').sort_index()

df.head()
# Out:
#             Close  Start   High    Low  Volume
# new_Date
# 2018-06-01  11900  11800  12100  11750   32062
# 2018-06-04  11900  11900  12200  11700   25171
# 2018-06-05  12150  11800  12250  11800   42485
# 2018-06-07  11950  12200  12300  11900   49088
# 2018-06-08  11950  11950  12200  11800   59258

# %%
df['Close'].plot(figsize=(8,3));

# %%
df[['Close', 'Volume']].plot(figsize=(8,3));

# %%
df['Close'].plot(label='Close',legend=True, figsize=(8,3))
df['Volume'].plot(secondary_y=True, style='r',label='Volume',legend=True);

# %%
df.plot(figsize=(8,3),colormap='tab20');

# %%
axes = df.plot(subplots=True, layout=(2,3), figsize=(18,6), sharex=True, sharey=False)

axes[0,0].xaxis.set_major_locator(plt.MaxNLocator(5))

# %%
fig, axes = plt.subplots(
    nrows=2,
    ncols=2,
    figsize=(16,8),
    constrained_layout=True
)

df['Close'].plot(ax=axes[0,0], style='r-.')
axes[0,0].set_title('Close')

df['Close'].plot(ax=axes[0,1], logy=True)
axes[0,1].set_title('Close (log)')

df['Close'].plot(ax=axes[1,0], kind='area',alpha=0.5)
axes[1,0].set_title('Close (area)')

df[['Start', 'High', 'Low', 'Close']].plot(ax=axes[1,1], legend=True)
df['Volume'].plot(ax=axes[1,1], legend=True, secondary_y=True)
axes[1,1].set_title('Price/Vloume')

plt.show()

# %%
import requests
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from copy import deepcopy

my_key = 'dpd-b51e64ab-29980b85d1841490c3fe53bee75835d1f301371fcdd5a8aa1b161d07ce6e7b0b'

def get_financials(stockCode, indicatorName, apiKey, consolidated=True, ttm=True):
    if consolidated:
        if ttm:
            url = f"https://api.dapada.io/company/getConsolidatedFinancialDataByTTM?indicatorName={indicatorName}&stockCode={stockCode}"

        else:
            url = f'https://api.dapada.io/company/getConsolidatedFinancialDataByCUR?indicatorName={indicatorName}&stockCode={stockCode}'

    else:
        if ttm:
            url = f'https://api.dapada.io/company/getSeparatedFinancialDataByTTM?indicatorName={indicatorName}&stockCode={stockCode}'

        else:
            url = f'https://api.dapada.io/company/getSeparatedFinancialDataByCUR?indicatorName={indicatorName}&stockCode={stockCode}'

    headers = {'Authorization':f'{apiKey}'}
    response = requests.get(url,headers=headers)
    result = response.json()
    return pd.DataFrame(result)

# %%
df_samsung = get_financials(
    stockCode='005930',
    indicatorName='영업이익',
    apiKey=my_key,
    consolidated=True,
    ttm=False
)

df_samsung['change'] = df_samsung['value'].pct_change()

df_samsung = df_samsung.set_index('quarter')

df_skhynix = get_financials(
    stockCode='000660',
    indicatorName='영업이익',
    apiKey=my_key,
    consolidated=True,
    ttm=False
)

df_skhynix['change'] = df_skhynix['value'].pct_change()

df_skhynix = df_skhynix.set_index('quarter')

df_samsung
# Out:
#                   value    change
# quarter
# 2023-Q3   2433534000000       NaN
# 2023-Q2    668547000000 -0.725277
# 2023-Q1    640178000000 -0.042434
# 2022-Q4   4306131000000  5.726459
# 2022-Q3   9389198000000  1.180426
# 2022-Q2  11098805000000  0.182082
# 2022-Q1  11324628000000  0.020347

# %%
df_samsung.style.format(precision=2,thousands=',',decimal='.')
# Out:
# <style type="text/css">
# </style>
# <table id="T_07853">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_07853_level0_col0" class="col_heading level0 col0" >value</th>
#       <th id="T_07853_level0_col1" class="col_heading level0 col1" >change</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >quarter</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_07853_level0_row0" class="row_heading level0 row0" >2023-Q3</th>
#       <td id="T_07853_row0_col0" class="data row0 col0" >2,433,534,000,000</td>
#       <td id="T_07853_row0_col1" class="data row0 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_07853_level0_row1" class="row_heading level0 row1" >2023-Q2</th>
#       <td id="T_07853_row1_col0" class="data row1 col0" >668,547,000,000</td>
#       <td id="T_07853_row1_col1" class="data row1 col1" >-0.73</td>
#     </tr>
#     <tr>
#       <th id="T_07853_level0_row2" class="row_heading level0 row2" >2023-Q1</th>
#       <td id="T_07853_row2_col0" class="data row2 col0" >640,178,000,000</td>
#       <td id="T_07853_row2_col1" class="data row2 col1" >-0.04</td>
#     </tr>
#     <tr>
#       <th id="T_07853_level0_row3" class="row_heading level0 row3" >2022-Q4</th>
#       <td id="T_07853_row3_col0" class="data row3 col0" >4,306,131,000,000</td>
#       <td id="T_07853_row3_col1" class="data row3 col1" >5.73</td>
#     </tr>
#     <tr>
#       <th id="T_07853_level0_row4" class="row_heading level0 row4" >2022-Q3</th>
#       <td id="T_07853_row4_col0" class="data row4 col0" >9,389,198,000,000</td>
#       <td id="T_07853_row4_col1" class="data row4 col1" >1.18</td>
#     </tr>
#     <tr>
#       <th id="T_07853_level0_row5" class="row_heading level0 row5" >2022-Q2</th>
#       <td id="T_07853_row5_col0" class="data row5 col0" >11,098,805,000,000</td>
#       <td id="T_07853_row5_col1" class="data row5 col1" >0.18</td>
#     </tr>
#     <tr>
#       <th id="T_07853_level0_row6" class="row_heading level0 row6" >2022-Q1</th>
#       <td id="T_07853_row6_col0" class="data row6 col0" >11,324,628,000,000</td>
#       <td id="T_07853_row6_col1" class="data row6 col1" >0.02</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_samsung.style.format_index(str.upper, axis=1)
# Out:
# <style type="text/css">
# </style>
# <table id="T_4f81c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4f81c_level0_col0" class="col_heading level0 col0" >VALUE</th>
#       <th id="T_4f81c_level0_col1" class="col_heading level0 col1" >CHANGE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >quarter</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4f81c_level0_row0" class="row_heading level0 row0" >2023-Q3</th>
#       <td id="T_4f81c_row0_col0" class="data row0 col0" >2433534000000</td>
#       <td id="T_4f81c_row0_col1" class="data row0 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_4f81c_level0_row1" class="row_heading level0 row1" >2023-Q2</th>
#       <td id="T_4f81c_row1_col0" class="data row1 col0" >668547000000</td>
#       <td id="T_4f81c_row1_col1" class="data row1 col1" >-0.725277</td>
#     </tr>
#     <tr>
#       <th id="T_4f81c_level0_row2" class="row_heading level0 row2" >2023-Q1</th>
#       <td id="T_4f81c_row2_col0" class="data row2 col0" >640178000000</td>
#       <td id="T_4f81c_row2_col1" class="data row2 col1" >-0.042434</td>
#     </tr>
#     <tr>
#       <th id="T_4f81c_level0_row3" class="row_heading level0 row3" >2022-Q4</th>
#       <td id="T_4f81c_row3_col0" class="data row3 col0" >4306131000000</td>
#       <td id="T_4f81c_row3_col1" class="data row3 col1" >5.726459</td>
#     </tr>
#     <tr>
#       <th id="T_4f81c_level0_row4" class="row_heading level0 row4" >2022-Q3</th>
#       <td id="T_4f81c_row4_col0" class="data row4 col0" >9389198000000</td>
#       <td id="T_4f81c_row4_col1" class="data row4 col1" >1.180426</td>
#     </tr>
#     <tr>
#       <th id="T_4f81c_level0_row5" class="row_heading level0 row5" >2022-Q2</th>
#       <td id="T_4f81c_row5_col0" class="data row5 col0" >11098805000000</td>
#       <td id="T_4f81c_row5_col1" class="data row5 col1" >0.182082</td>
#     </tr>
#     <tr>
#       <th id="T_4f81c_level0_row6" class="row_heading level0 row6" >2022-Q1</th>
#       <td id="T_4f81c_row6_col0" class="data row6 col0" >11324628000000</td>
#       <td id="T_4f81c_row6_col1" class="data row6 col1" >0.020347</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_samsung.style.format_index(str.lower, axis=0)
# Out:
# <style type="text/css">
# </style>
# <table id="T_e5eb8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e5eb8_level0_col0" class="col_heading level0 col0" >value</th>
#       <th id="T_e5eb8_level0_col1" class="col_heading level0 col1" >change</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >quarter</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e5eb8_level0_row0" class="row_heading level0 row0" >2023-q3</th>
#       <td id="T_e5eb8_row0_col0" class="data row0 col0" >2433534000000</td>
#       <td id="T_e5eb8_row0_col1" class="data row0 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_e5eb8_level0_row1" class="row_heading level0 row1" >2023-q2</th>
#       <td id="T_e5eb8_row1_col0" class="data row1 col0" >668547000000</td>
#       <td id="T_e5eb8_row1_col1" class="data row1 col1" >-0.725277</td>
#     </tr>
#     <tr>
#       <th id="T_e5eb8_level0_row2" class="row_heading level0 row2" >2023-q1</th>
#       <td id="T_e5eb8_row2_col0" class="data row2 col0" >640178000000</td>
#       <td id="T_e5eb8_row2_col1" class="data row2 col1" >-0.042434</td>
#     </tr>
#     <tr>
#       <th id="T_e5eb8_level0_row3" class="row_heading level0 row3" >2022-q4</th>
#       <td id="T_e5eb8_row3_col0" class="data row3 col0" >4306131000000</td>
#       <td id="T_e5eb8_row3_col1" class="data row3 col1" >5.726459</td>
#     </tr>
#     <tr>
#       <th id="T_e5eb8_level0_row4" class="row_heading level0 row4" >2022-q3</th>
#       <td id="T_e5eb8_row4_col0" class="data row4 col0" >9389198000000</td>
#       <td id="T_e5eb8_row4_col1" class="data row4 col1" >1.180426</td>
#     </tr>
#     <tr>
#       <th id="T_e5eb8_level0_row5" class="row_heading level0 row5" >2022-q2</th>
#       <td id="T_e5eb8_row5_col0" class="data row5 col0" >11098805000000</td>
#       <td id="T_e5eb8_row5_col1" class="data row5 col1" >0.182082</td>
#     </tr>
#     <tr>
#       <th id="T_e5eb8_level0_row6" class="row_heading level0 row6" >2022-q1</th>
#       <td id="T_e5eb8_row6_col0" class="data row6 col0" >11324628000000</td>
#       <td id="T_e5eb8_row6_col1" class="data row6 col1" >0.020347</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_samsung.style.relabel_index(['영업이익','영업이익증가율'], axis=1)
# Out:
# <style type="text/css">
# </style>
# <table id="T_f3d7c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f3d7c_level0_col0" class="col_heading level0 col0" >영업이익</th>
#       <th id="T_f3d7c_level0_col1" class="col_heading level0 col1" >영업이익증가율</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >quarter</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f3d7c_level0_row0" class="row_heading level0 row0" >2023-Q3</th>
#       <td id="T_f3d7c_row0_col0" class="data row0 col0" >2433534000000</td>
#       <td id="T_f3d7c_row0_col1" class="data row0 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_f3d7c_level0_row1" class="row_heading level0 row1" >2023-Q2</th>
#       <td id="T_f3d7c_row1_col0" class="data row1 col0" >668547000000</td>
#       <td id="T_f3d7c_row1_col1" class="data row1 col1" >-0.725277</td>
#     </tr>
#     <tr>
#       <th id="T_f3d7c_level0_row2" class="row_heading level0 row2" >2023-Q1</th>
#       <td id="T_f3d7c_row2_col0" class="data row2 col0" >640178000000</td>
#       <td id="T_f3d7c_row2_col1" class="data row2 col1" >-0.042434</td>
#     </tr>
#     <tr>
#       <th id="T_f3d7c_level0_row3" class="row_heading level0 row3" >2022-Q4</th>
#       <td id="T_f3d7c_row3_col0" class="data row3 col0" >4306131000000</td>
#       <td id="T_f3d7c_row3_col1" class="data row3 col1" >5.726459</td>
#     </tr>
#     <tr>
#       <th id="T_f3d7c_level0_row4" class="row_heading level0 row4" >2022-Q3</th>
#       <td id="T_f3d7c_row4_col0" class="data row4 col0" >9389198000000</td>
#       <td id="T_f3d7c_row4_col1" class="data row4 col1" >1.180426</td>
#     </tr>
#     <tr>
#       <th id="T_f3d7c_level0_row5" class="row_heading level0 row5" >2022-Q2</th>
#       <td id="T_f3d7c_row5_col0" class="data row5 col0" >11098805000000</td>
#       <td id="T_f3d7c_row5_col1" class="data row5 col1" >0.182082</td>
#     </tr>
#     <tr>
#       <th id="T_f3d7c_level0_row6" class="row_heading level0 row6" >2022-Q1</th>
#       <td id="T_f3d7c_row6_col0" class="data row6 col0" >11324628000000</td>
#       <td id="T_f3d7c_row6_col1" class="data row6 col1" >0.020347</td>
#     </tr>
#   </tbody>
# </table>

# %%
new_dates = ['2023.09', '2023.06', '2023.03', '2022.12', '2022.09', '2022.06', '2022.03']
df_samsung.style.relabel_index(new_dates, axis=0)
# Out:
# <style type="text/css">
# </style>
# <table id="T_bfe2c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bfe2c_level0_col0" class="col_heading level0 col0" >value</th>
#       <th id="T_bfe2c_level0_col1" class="col_heading level0 col1" >change</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >quarter</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bfe2c_level0_row0" class="row_heading level0 row0" >2023.09</th>
#       <td id="T_bfe2c_row0_col0" class="data row0 col0" >2433534000000</td>
#       <td id="T_bfe2c_row0_col1" class="data row0 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_bfe2c_level0_row1" class="row_heading level0 row1" >2023.06</th>
#       <td id="T_bfe2c_row1_col0" class="data row1 col0" >668547000000</td>
#       <td id="T_bfe2c_row1_col1" class="data row1 col1" >-0.725277</td>
#     </tr>
#     <tr>
#       <th id="T_bfe2c_level0_row2" class="row_heading level0 row2" >2023.03</th>
#       <td id="T_bfe2c_row2_col0" class="data row2 col0" >640178000000</td>
#       <td id="T_bfe2c_row2_col1" class="data row2 col1" >-0.042434</td>
#     </tr>
#     <tr>
#       <th id="T_bfe2c_level0_row3" class="row_heading level0 row3" >2022.12</th>
#       <td id="T_bfe2c_row3_col0" class="data row3 col0" >4306131000000</td>
#       <td id="T_bfe2c_row3_col1" class="data row3 col1" >5.726459</td>
#     </tr>
#     <tr>
#       <th id="T_bfe2c_level0_row4" class="row_heading level0 row4" >2022.09</th>
#       <td id="T_bfe2c_row4_col0" class="data row4 col0" >9389198000000</td>
#       <td id="T_bfe2c_row4_col1" class="data row4 col1" >1.180426</td>
#     </tr>
#     <tr>
#       <th id="T_bfe2c_level0_row5" class="row_heading level0 row5" >2022.06</th>
#       <td id="T_bfe2c_row5_col0" class="data row5 col0" >11098805000000</td>
#       <td id="T_bfe2c_row5_col1" class="data row5 col1" >0.182082</td>
#     </tr>
#     <tr>
#       <th id="T_bfe2c_level0_row6" class="row_heading level0 row6" >2022.03</th>
#       <td id="T_bfe2c_row6_col0" class="data row6 col0" >11324628000000</td>
#       <td id="T_bfe2c_row6_col1" class="data row6 col1" >0.020347</td>
#     </tr>
#   </tbody>
# </table>

# %%
data_styler = df_samsung.style.format(precision=2, thousands=',',decimal='.')
stat_styler = df_samsung.describe().style.format(precision=2,thousands=',',decimal='.')

data_styler.concat(stat_styler)
# Out:
# <style type="text/css">
# </style>
# <table id="T_c4c05">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c4c05_level0_col0" class="col_heading level0 col0" >value</th>
#       <th id="T_c4c05_level0_col1" class="col_heading level0 col1" >change</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >quarter</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c4c05_level0_row0" class="row_heading level0 row0" >2023-Q3</th>
#       <td id="T_c4c05_row0_col0" class="data row0 col0" >2,433,534,000,000</td>
#       <td id="T_c4c05_row0_col1" class="data row0 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_c4c05_level0_row1" class="row_heading level0 row1" >2023-Q2</th>
#       <td id="T_c4c05_row1_col0" class="data row1 col0" >668,547,000,000</td>
#       <td id="T_c4c05_row1_col1" class="data row1 col1" >-0.73</td>
#     </tr>
#     <tr>
#       <th id="T_c4c05_level0_row2" class="row_heading level0 row2" >2023-Q1</th>
#       <td id="T_c4c05_row2_col0" class="data row2 col0" >640,178,000,000</td>
#       <td id="T_c4c05_row2_col1" class="data row2 col1" >-0.04</td>
#     </tr>
#     <tr>
#       <th id="T_c4c05_level0_row3" class="row_heading level0 row3" >2022-Q4</th>
#       <td id="T_c4c05_row3_col0" class="data row3 col0" >4,306,131,000,000</td>
#       <td id="T_c4c05_row3_col1" class="data row3 col1" >5.73</td>
#     </tr>
#     <tr>
#       <th id="T_c4c05_level0_row4" class="row_heading level0 row4" >2022-Q3</th>
#       <td id="T_c4c05_row4_col0" class="data row4 col0" >9,389,198,000,000</td>
#       <td id="T_c4c05_row4_col1" class="data row4 col1" >1.18</td>
#     </tr>
#     <tr>
#       <th id="T_c4c05_level0_row5" class="row_heading level0 row5" >2022-Q2</th>
#       <td id="T_c4c05_row5_col0" class="data row5 col0" >11,098,805,000,000</td>
#       <td id="T_c4c05_row5_col1" class="data row5 col1" >0.18</td>
#     </tr>
#     <tr>
#       <th id="T_c4c05_level0_row6" class="row_heading level0 row6" >2022-Q1</th>
#       <td id="T_c4c05_row6_col0" class="data row6 col0" >11,324,628,000,000</td>
#       <td id="T_c4c05_row6_col1" class="data row6 col1" >0.02</td>
#     </tr>
#     <tr>
#       <th id="T_c4c05_level0_foot0_row0" class="foot0_row_heading level0 foot0_row0" >count</th>
#       <td id="T_c4c05_foot0_row0_col0" class="foot0_data foot0_row0 col0" >7.00</td>
#       <td id="T_c4c05_foot0_row0_col1" class="foot0_data foot0_row0 col1" >6.00</td>
#     </tr>
#     <tr>
#       <th id="T_c4c05_level0_foot0_row1" class="foot0_row_heading level0 foot0_row1" >mean</th>
#       <td id="T_c4c05_foot0_row1_col0" class="foot0_data foot0_row1 col0" >5,694,431,571,428.57</td>
#       <td id="T_c4c05_foot0_row1_col1" class="foot0_data foot0_row1 col1" >1.06</td>
#     </tr>
#     <tr>
#       <th id="T_c4c05_level0_foot0_row2" class="foot0_row_heading level0 foot0_row2" >std</th>
#       <td id="T_c4c05_foot0_row2_col0" class="foot0_data foot0_row2 col0" >4,794,501,873,310.12</td>
#       <td id="T_c4c05_foot0_row2_col1" class="foot0_data foot0_row2 col1" >2.37</td>
#     </tr>
#     <tr>
#       <th id="T_c4c05_level0_foot0_row3" class="foot0_row_heading level0 foot0_row3" >min</th>
#       <td id="T_c4c05_foot0_row3_col0" class="foot0_data foot0_row3 col0" >640,178,000,000.00</td>
#       <td id="T_c4c05_foot0_row3_col1" class="foot0_data foot0_row3 col1" >-0.73</td>
#     </tr>
#     <tr>
#       <th id="T_c4c05_level0_foot0_row4" class="foot0_row_heading level0 foot0_row4" >25%</th>
#       <td id="T_c4c05_foot0_row4_col0" class="foot0_data foot0_row4 col0" >1,551,040,500,000.00</td>
#       <td id="T_c4c05_foot0_row4_col1" class="foot0_data foot0_row4 col1" >-0.03</td>
#     </tr>
#     <tr>
#       <th id="T_c4c05_level0_foot0_row5" class="foot0_row_heading level0 foot0_row5" >50%</th>
#       <td id="T_c4c05_foot0_row5_col0" class="foot0_data foot0_row5 col0" >4,306,131,000,000.00</td>
#       <td id="T_c4c05_foot0_row5_col1" class="foot0_data foot0_row5 col1" >0.10</td>
#     </tr>
#     <tr>
#       <th id="T_c4c05_level0_foot0_row6" class="foot0_row_heading level0 foot0_row6" >75%</th>
#       <td id="T_c4c05_foot0_row6_col0" class="foot0_data foot0_row6 col0" >10,244,001,500,000.00</td>
#       <td id="T_c4c05_foot0_row6_col1" class="foot0_data foot0_row6 col1" >0.93</td>
#     </tr>
#     <tr>
#       <th id="T_c4c05_level0_foot0_row7" class="foot0_row_heading level0 foot0_row7" >max</th>
#       <td id="T_c4c05_foot0_row7_col0" class="foot0_data foot0_row7 col0" >11,324,628,000,000.00</td>
#       <td id="T_c4c05_foot0_row7_col1" class="foot0_data foot0_row7 col1" >5.73</td>
#     </tr>
#   </tbody>
# </table>
